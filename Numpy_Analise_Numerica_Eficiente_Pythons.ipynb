# %% [markdown]
# <a href="https://colab.research.google.com/github/thsilvar/numpy-analise-numerica-eficiente-pythons/blob/main/Numpy_Analise_Numerica_Eficiente_Pythons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
